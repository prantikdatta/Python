# %% [markdown]
# ## This file has all the codes for pandas learning.
# ## Enjoy and have fun!!

# %% [markdown]
# We have movies dataset. We want to do some basic analysis such as,
#
# 1. What is the min, max and average rating for all movies?
# 1. What is the min, max and average rating for all bollywood movies?
# 1. What is the min, max and average rating for all hollywood movies?
#
# We will see how this can be done first without using Pandas and then using Pandas

# %% [markdown]
# # Option 1 - Movies analysis without using Pandas

# %%
import csv

def calculate_rating_stats(data, industry=None):
    ratings = []
    for row in data:
        if row[3]!='NULL' and (not industry or row[1]==industry):
            ratings.append(float(row[3]))
    max_rating = max(ratings)
    min_rating = min(ratings)
    avg_rating = sum(ratings) / len(ratings)
    return max_rating, min_rating, avg_rating

with open('movies.csv') as f:
    data = list(csv.reader(f))
    header = data[0]
    data = data[1:]
    
    max_rating, min_rating, avg_rating = calculate_rating_stats(data)
    print(f"All records: Min rating = {min_rating}, Max rating = {max_rating}, Avg rating = {avg_rating}")
    
    max_rating, min_rating, avg_rating = calculate_rating_stats(data, industry="Bollywood")
    print(f"Bollywood: Min rating = {min_rating}, Max rating = {max_rating}, Avg rating = {avg_rating}")
    
    max_rating, min_rating, avg_rating = calculate_rating_stats(data, industry="Hollywood")
    print(f"Hollywood: Min rating = {min_rating}, Max rating = {max_rating}, Avg rating = {avg_rating}")
# Out:
# All records: Min rating = 1.9, Max rating = 9.3, Avg rating = 7.919444444444445
# Bollywood: Min rating = 1.9, Max rating = 8.4, Avg rating = 7.65625
# Hollywood: Min rating = 6.8, Max rating = 9.3, Avg rating = 8.129999999999999

# %% [markdown]
# # Option 2 - Movies analysis using Pandas

# %%
#importing pandas library

import pandas as pd

# %%
df = pd.read_csv('movies.csv')
df.head(5) #print the first 5 rows from top
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# 3      USD  English
# 4      USD  English

# %%
df.tail(5) #printing last 5 rows of the dataset
# Out:
#                         title   industry  release_year  imdb_rating  \
# 32                  Shershaah  Bollywood          2021          8.4
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 32   Dharma Productions   500.0    950.0  Millions      INR    Hindi
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
df.sample(5) #random 5 rows from the dataset
# Out:
#                         title   industry  release_year  imdb_rating  \
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 17          Avengers: Endgame  Hollywood          2019          8.4
# 26        Munna Bhai M.B.B.S.  Bollywood          2003          8.1
# 8                   Gladiator  Hollywood          2000          8.5
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
#
#                       studio  budget  revenue      unit currency language
# 33             Hombale Films     1.0     12.5  Billions      INR  Kannada
# 17            Marvel Studios   400.0   2798.0  Millions      USD  English
# 26  Vinod Chopra Productions   100.0    410.0  Millions      INR    Hindi
# 8       Universal Pictures     103.0    460.5  Millions      USD  English
# 34       Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu

# %%
df[2:6] #index operations just like list; where it means print rows from 2 to 6, 6 isn't included
# Out:
#                       title   industry  release_year  imdb_rating  \
# 2     Thor: The Dark World   Hollywood          2013          6.8
# 3           Thor: Ragnarok   Hollywood          2017          7.9
# 4   Thor: Love and Thunder   Hollywood          2022          6.8
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 2             Marvel Studios   165.0    644.8  Millions      USD  English
# 3             Marvel Studios   180.0    854.0  Millions      USD  English
# 4             Marvel Studios   250.0    670.0  Millions      USD  English
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df.shape #means dataframe has 37 rows and 10 cols
# Out:
# (37, 10)

# %%
#prints value in the col using index operator i.e. []

# df['imdb_rating']

# %%
#prints value like a property as if its a class object
#and the type of col in a dataframe object is called 'series'

type(df.imdb_rating)
# Out:
# pandas.Series

# %% [markdown]
# #### On pandas series you get a lot of functions

# %%
# How to check what are the functions use <dir>

dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pandas_priority__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_align_for_op',
#  '_align_frame',
#  '_align_series',
#  '_append_internal',
#  '_arith_method',
#  '_arith_method_with_reindex',
#  '_attrs',
#  '_box_col_values',
#  '_can_fast_transpose',
#  '_check_copy_deprecation',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_label_or_level_ambiguity',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_result',
#  '_constructor',
#  '_constructor_from_mgr',
#  '_constructor_sliced',
#  '_constructor_sliced_from_mgr',
#  '_dir_additions',
#  '_dir_deletions',
#  '_dispatch_frame_op',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_flags',
#  '_flex_arith_method',
#  '_flex_cmp_method',
#  '_from_arrays',
#  '_from_mgr',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_index_resolvers',
#  '_get_item',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_get_values_for_csv',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_getitem_slice',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_iset_item',
#  '_iset_item_mgr',
#  '_iset_not_inplace',
#  '_iter_column_arrays',
#  '_ixs',
#  '_logical_func',
#  '_logical_method',
#  '_maybe_align_series_as_frame',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_pad_or_backfill',
#  '_reduce',
#  '_reduce_axis1',
#  '_reindex_axes',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_rename',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_sanitize_column',
#  '_series',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_item',
#  '_set_item_frame_value',
#  '_set_item_mgr',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_shift_with_freq',
#  '_should_reindex_frame_op',
#  '_slice',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_to_dict_of_blocks',
#  '_to_latex_via_styler',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'apply',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'between_time',
#  'bfill',
#  'boxplot',
#  'budget',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'currency',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_arrow',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'imdb_rating',
#  'index',
#  'industry',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isetitem',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'language',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lt',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'release_year',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'revenue',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'std',
#  'studio',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swaplevel',
#  'tail',
#  'take',
#  'title',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_hdf',
#  'to_html',
#  'to_iceberg',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_orc',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'to_xml',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unit',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs']

# %% [markdown]
# ### Q1. What is the min, max and average rating for all movies?

# %%
df.imdb_rating.min(), df.imdb_rating.max(), df.imdb_rating.mean()
# Out:
# (np.float64(1.9), np.float64(9.3), np.float64(7.919444444444445))

# %%
print(
    float(df.imdb_rating.min()),
    float(df.imdb_rating.max()),
    float(df.imdb_rating.mean())
)
# Out:
# 1.9 9.3 7.919444444444445

# %%
df['imdb_rating'].describe()
# Out:
# count    36.000000
# mean      7.919444
# std       1.204947
# min       1.900000
# 25%       7.800000
# 50%       8.100000
# 75%       8.400000
# max       9.300000
# Name: imdb_rating, dtype: float64

# %% [markdown]
# ### Q2. What is the min, max and average rating for all bollywood movies?

# %%
df_b = df[df.industry == 'Bollywood']
df_h = df[df.industry == 'Hollywood']

# %%
df_b['imdb_rating'].describe()
# Out:
# count    16.000000
# mean      7.656250
# std       1.576058
# min       1.900000
# 25%       7.900000
# 50%       8.100000
# 75%       8.300000
# max       8.400000
# Name: imdb_rating, dtype: float64

# %%
df_h['imdb_rating'].describe()
# Out:
# count    20.000000
# mean      8.130000
# std       0.780081
# min       6.800000
# 25%       7.800000
# 50%       8.300000
# 75%       8.600000
# max       9.300000
# Name: imdb_rating, dtype: float64

# %%
df = pd.read_csv("movies.csv")
print("All movies: Min=", df.imdb_rating.min(), "Max=", df.imdb_rating.max(), "Avg=", df.imdb_rating.mean())

df_b = df[df.industry=="Bollywood"]
df_h = df[df.industry=="Hollywood"]

print("Bollywood: Min=", df_b.imdb_rating.min(), "Max=", df_b.imdb_rating.max(), "Avg=", df_b.imdb_rating.mean())
print("Hollywood: Min=", df_h.imdb_rating.min(), "Max=", df_h.imdb_rating.max(), "Avg=", df_h.imdb_rating.mean())
# Out:
# All movies: Min= 1.9 Max= 9.3 Avg= 7.919444444444445
# Bollywood: Min= 1.9 Max= 8.4 Avg= 7.656250000000001
# Hollywood: Min= 6.8 Max= 9.3 Avg= 8.130000000000003
